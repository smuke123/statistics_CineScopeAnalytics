# %% [markdown]
# **<h1> <font color = '#00E6FE'> Proyecto de Estadistica I <br> </font> </h1>**
#
#  <h1> <font color = '#00E6FE'> Definición y Análisis del Éxito Cinematográfico: Un Enfoque Multidimensional Basado en Indicadores Cuantitativos y Cualitativos 🎬</font> </h1>
#
#
#
# *   <strong>Cesar Alejandro Soto Paipa
# *   Edgar Santiago Ariza García
# *   Jeison Fernando Guarguati Anaya</strong>

# %% [markdown]
# # <font color='#9BFDFF'>**Introducción**</font>
#
# ---

# %% [markdown]
# <h3>El éxito de una película es un concepto complejo que involucra una variedad de factores, más allá de los ingresos brutos obtenidos en taquilla. En este proyecto, se busca explorar cómo distintos indicadores pueden definir el éxito de una película, no solo desde el punto de vista financiero, sino también desde el reconocimiento crítico y la aceptación del público.
#
# <h3>Para ello, se utiliza un dataset que contiene información sobre 3,755 películas, con variables como la duración, el presupuesto, los ingresos brutos, las puntuaciones en IMDb, los votos de usuarios, y más. A través del análisis de estos datos, se establecerán criterios de éxito cinematográfico que permitirán evaluar las películas bajo diversas perspectivas.
#
# <h3>El análisis se centrará en cuatro aspectos clave: la puntuación en IMDb, los ingresos brutos, el número de votos de usuarios, y el reconocimiento crítico. Estos indicadores se seleccionan debido a su relevancia en estudios previos sobre el tema y su capacidad para reflejar tanto la popularidad de las películas como su valoración a largo plazo.

# %% [markdown]
# # <font color='#9BFDFF'>**Marco teórico**</font>
#
#
# ---

# %% [markdown]
# <h3>El éxito de una película se puede medir desde diferentes perspectivas, dependiendo de los factores considerados más relevantes. Tradicionalmente, se ha asociado el éxito con los ingresos obtenidos en taquilla, sin embargo, esta visión resulta limitada, ya que no refleja la totalidad de los logros que puede alcanzar una película. El éxito cinematográfico es un concepto multidimensional que abarca tanto aspectos financieros como artísticos y culturales.
#
# <h3>A lo largo de los años, se han propuesto diversas definiciones de éxito cinematográfico que incluyen factores como la rentabilidad financiera, el reconocimiento crítico, la popularidad entre los espectadores y el impacto cultural. Los estudios muestran que las películas que son exitosas a largo plazo no solo destacan por sus ingresos en taquilla, sino también por su capacidad para ser apreciadas por la crítica, su longevidad en la memoria colectiva y su influencia en la sociedad.

# %% [markdown]
# ## <font color='#9BFDFF'>Criterios y justificación</font>

# %% [markdown]
# Para este análisis, se seleccionaron cuatro criterios fundamentales que se consideran indicadores clave del éxito cinematográfico:<br><br>
#
# **1) Puntuación en IMDb (≥ 7.0):**
#
# Justificación: IMDb es una de las plataformas más influyentes para la opinión
# del público. Las películas con una puntuación igual o superior a 7.0 suelen ser vistas como de alta calidad, ya que reflejan una valoración positiva por parte de una audiencia amplia. Un estudio de Wallace et al. (2016) sugiere que las películas con alta calificación en IMDb tienden a mantenerse relevantes a largo plazo, pues la valoración del público influye directamente en su permanencia en la memoria colectiva.
#
# **Fuente:** Wallace, W., Seigerman, A., & Holbrook, M. (2016). The Role of Critics in the Culture of the Movie Industry. Journal of Marketing, 61(2), 42–55. <br><br>
#
# **2) Ingresos Brutos (superiores a la mediana del dataset):**
#
# Justificación: Los ingresos brutos son un indicador directo de la rentabilidad financiera de una película. Sin embargo, los ingresos deben analizarse en relación con el presupuesto de producción para obtener una medida precisa de éxito financiero. De Vany y Walls (1999) argumentan que el retorno de inversión es un factor crítico, pero debe ser considerado dentro de un contexto que contemple la incertidumbre inherente a la industria cinematográfica.
#
# **Fuente:** De Vany, A., & Walls, W. D. (1999). Uncertainty in the Movie Industry: Does Star Power Reduce the Terror of the Box Office? Journal of Cultural Economics, 23(4), 285–318.
# <br><br>
#
# **3) Votos de Usuarios (más de 100,000 votos):**
#
# Justificación: El número de votos y reseñas en plataformas como IMDb refleja la popularidad y aceptación de una película entre el público general. Las películas que generan una mayor interacción y participación por parte de los usuarios tienden a ser más exitosas en términos de popularidad y tienen un impacto más duradero. Mishra y Rout (2020) destacan que las métricas sociales y de engagement digital permiten una mejor estimación del éxito de una película desde la perspectiva del público general.
#
# **Fuente:** Mishra, A., & Rout, H. K. (2020). Social Media and the Film Industry: Measuring Popularity and Success. International Journal of Communication, 14, 1365–1383.
# <br><br>
#
# **4) Reconocimiento Crítico (premios y distinciones):**
#
# Justificación: El reconocimiento crítico es esencial para evaluar la importancia artística de una película. Las películas que reciben elogios de la crítica y ganan premios importantes, como los Óscar o los Globos de Oro, tienen un valor cultural significativo que las distingue de otras películas. Konnikova (2014) menciona que algunas películas, como "Frozen", logran un impacto cultural profundo más allá de su rendimiento financiero, gracias a su resonancia emocional y narrativa.
#
# **Fuente:** Konnikova, M. (2014). How ‘Frozen’ Took Over the World. The New Yorker. https://www.newyorker.com

# %% [markdown]
# # <font color='#9BFDFF'>**Descripción del Dataset**</font>
#
#
#
# ---

# %% [markdown]
# <h3>El dataset utilizado obtenido de Kaggle en este proyecto proviene de datos IMDb y contiene información de 3,755 películas, con un total de 28 columnas. Los datos incluyen variables tanto cuantitativas como cualitativas que permiten evaluar el rendimiento y las características de las películas desde diferentes perspectivas. Algunas de sus columnas tienen información como:<br><br>
#
#
#
# *   **Puntuación en IMDb:** Valoración media de los usuarios.
# *   **Duración:** La duración de la película en minutos.
# *   **Presupuesto y Ingresos Brutos:** Indicadores clave para medir el éxito financiero.
# *   **Número de votos:** Refleja el nivel de interacción del público con la película.
# *   **Facebook Likes:** Mide la popularidad en redes sociales, con variables como los "likes" de actores y directores.
# *   **Géneros y Palabras clave del argumento:** Ofrecen información sobre el tipo de película y sus temas.
# *   **Reconocimiento Crítico:** El número de críticas y la puntuación asociada reflejan el impacto en el ámbito profesional.

# %% [markdown]
# # <font color='#9BFDFF'>**Objetivos**</font>
#
#
# ---

# %% [markdown]
# <h3>
# 1.  Analizar la relación entre la puntuación en IMDb y los ingresos brutos de las películas para entender si una mayor puntuación correlaciona con un mayor éxito financiero.
#
# <h3>
# 2. Identificar los géneros de películas que tienden a obtener mayores ingresos en taquilla.
#
# <h3>
# 3. Evaluar si la duración de las películas tiene algún efecto sobre la valoración del público en IMDb.
#
# <h3>
# 4. Consultar la relación entre el número de votos de usuarios en IMDb y el éxito crítico (premios y distinciones).
#
# <h3>
# 5. Establecer un criterio para identificar las películas más exitosas según los indicadores de éxito definidos (IMDb, ingresos brutos, número de votos, y reconocimiento crítico).

# %% [markdown]
# # <font color='#5BFFB1'>**Desarrollo**</font>
#
# ---

# %% [markdown]
# ## **Carga del DataSet**

# %%
# Librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Acceso a drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cargue del dataset
df = pd.read_csv('/content/drive/MyDrive/UIS/ESTADISTICA_I/DATASET/movie_metadata.csv')

# Quitar espacios vacios
df = df.dropna()

# Mostrar datos
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
# Columnas del datset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3755 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      3755 non-null   object
#  1   director_name              3755 non-null   object
#  2   num_critic_for_reviews     3755 non-null   float64
#  3   duration                   3755 non-null   float64
#  4   director_facebook_likes    3755 non-null   float64
#  5   actor_3_facebook_likes     3755 non-null   float64
#  6   actor_2_name               3755 non-null   object
#  7   actor_1_facebook_likes     3755 non-null   float64
#  8   gross                      3755 non-null   float64
#  9   genres                     3755 non-null   object
#  10  actor_1_name               3755 non-null   object
#  11  movie_title                3755 non-null   object
#  12  num_voted_users            3755 non-null   int64
# ...

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 1: Distribución de la Puntuación en IMDb</font>

# %% [markdown]
# Visualizar no solo la mediana y los cuartiles, sino también la densidad de las puntuaciones en diferentes rangos. Entender la forma de la distribución y si existen valores extremos

# %%
# Violin plot


df = df[df['imdb_score'].notnull()]

# Crear columna ficticia para que seaborn lo trate como categórico
df['dummy'] = 'IMDb'

# Configurar el estilo similar a ggplot2
sns.set(style="whitegrid")

# Crear el violin plot
plt.figure(figsize=(6, 8))
sns.violinplot(x='dummy', y='imdb_score', data=df, inner='box', palette=['#87CEEB'])

# Ajustes de título y etiquetas
plt.title('Distribución de la Puntuación en IMDb', fontsize=14)
plt.xlabel('')
plt.ylabel('IMDb Score', fontsize=12)

# Mostrar la gráfica
plt.show()
# Out:
# <ipython-input-13-925c6753cf1b>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='dummy', y='imdb_score', data=df, inner='box', palette=['#87CEEB'])

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 2: Ingresos Brutos Normalizados por Presupuesto</font>

# %% [markdown]
# Permite comparar películas en términos de su retorno de inversión, destacando aquellas que tienen un alto rendimiento financiero en comparación con su presupuesto.

# %%
# Barras Normalizado

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 3: Duración de la Película vs. Puntuación en IMDb</font>

# %% [markdown]
# Identificar si las películas largas o cortas tienden a obtener mejores o peores calificaciones y revisar si existen posibles valores atípicos.

# %%
# Box Plot

# Agrupar duración en categorías
bins = [0, 80, 100, 120, 140, 300]
labels = ['<80 min', '80-100 min', '100-120 min', '120-140 min', '>140 min']
df['duration_group'] = pd.cut(df['duration'], bins=bins, labels=labels)

# Crear el box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='duration_group', y='imdb_score', data=df, palette='Set1')

plt.title('Duración de la Película vs. Puntuación en IMDb')
plt.xlabel('Duración de la Película')
plt.ylabel('Puntuación IMDb')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-5cec2e0a3be9>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='duration_group', y='imdb_score', data=df, palette='Set1')

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 4: Número de Votos de Usuarios por Género</font>

# %% [markdown]
# Ver qué géneros generan mayor interacción del público, lo que puede ser un buen indicativo de la popularidad.

# %%
# Gráfico de barras

# Expandir los géneros a filas individuales
df_exploded = df.copy()
df_exploded['genres'] = df_exploded['genres'].str.split('|')
df_exploded = df_exploded.explode('genres')

# Agrupar por género individual
votos_por_genero_individual = df_exploded.groupby('genres')['num_voted_users'].sum().sort_values(ascending=False).head(10)

# Graficar nuevamente
plt.figure(figsize=(12, 6))
sns.barplot(x=votos_por_genero_individual.index, y=votos_por_genero_individual.values, palette='viridis')
plt.title('Número de Votos de Usuarios por Género Individual (Top 10)')
plt.xlabel('Género')
plt.ylabel('Número de Votos de Usuarios')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-9d75666b7e48>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=votos_por_genero_individual.index, y=votos_por_genero_individual.values, palette='viridis')

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 5: Distribución de Ingresos Brutos por Género</font>

# %% [markdown]
#  Identificar qué géneros tienden a generar más ingresos y la dispersión dentro de cada uno.

# %%
# Violin Plot


# Limpiar y tomar solo el primer género
df_clean = df[['gross', 'genres']].dropna()
df_clean['main_genre'] = df_clean['genres'].apply(lambda x: x.split('|')[0])

# Seleccionar los 10 géneros más frecuentes
top_genres = df_clean['main_genre'].value_counts().nlargest(10).index
df_top = df_clean[df_clean['main_genre'].isin(top_genres)]

# Graficar
plt.figure(figsize=(12, 6))
sns.violinplot(x='main_genre', y='gross', data=df_top, inner='box', palette='Set2')
plt.title('Distribución de Ingresos Brutos por Género Principal')
plt.xlabel('Género')
plt.ylabel('Ingresos Brutos (gross)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-d0ba8ba94d7e>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='main_genre', y='gross', data=df_top, inner='box', palette='Set2')

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 6: Relación entre el Número de Votos y el Reconocimiento Crítico</font>

# %% [markdown]
# **Objetivo**: Explorar las correlaciones lineales entre variables cuantitativas como presupuesto, duración, puntuación IMDB y ganancias (`gross`) para identificar relaciones potenciales.
#  **Descripción**: Este heatmap muestra una matriz de correlaciones de Pearson entre seis variables numéricas del dataset. El color azul indica correlaciones negativas, el rojo correlaciones positivas, y el valor numérico representa la magnitud de la correlación.
#  **Interpretación**:
#  - Una correlación cercana a **1** indica una relación lineal fuerte y positiva.
#  - Una correlación cercana a **-1** indica una relación lineal fuerte pero negativa.
#  - Una correlación cercana a **0** sugiere que no hay relación lineal.
#  **Conclusiones preliminares**:
#  - Existe una correlación positiva entre `budget` con `num_critic_for_reviews` y `movie_facebook_likes`, lo que sugiere que la popularidad y mayor exponencia al publico puede asociarse con mayores ganancias.
# - `imdb_score` tiene una relación débil con las demás variables, indicando que una buena puntuación no garantiza éxito económico.

# %%
# Heatmap
import pandas as pd

for col in ['budget', 'gross', 'duration', 'num_critic_for_reviews', 'imdb_score', 'movie_facebook_likes']:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df = df.dropna(subset=['budget', 'duration'])

df_num = df[['budget', 'gross', 'duration', 'num_critic_for_reviews', 'imdb_score', 'movie_facebook_likes']]

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df_num.corr(), annot=True, cmap="bwr", fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlaciones Lineal Cinematica')
plt.show()

# %% [markdown]
# **Relación entre variables explicativas y las ganancias (Gross)**
#
# **Objetivo**: Analizar la relación individual entre tres variables predictoras (`imdb_score`, `num_voted_users`, `cast_total_facebook_likes`) y las ganancias (`gross`) para detectar tendencias.
#
# ### 1. IMDB Score vs Gross
# **Interpretación**: Se observa una tendencia levemente creciente, pero con alta dispersión. A pesar de que una mejor puntuación puede influir positivamente, no es un factor decisivo por sí solo.
#
# ### 2. Número de votos vs Gross
# **Interpretación**: Aquí sí hay una **relación más clara**. A medida que aumenta el número de votos de usuarios, también tiende a aumentar la ganancia. Esto puede indicar que películas más vistas o discutidas tienen mejor desempeño económico.
#
# ### 3. Likes en Facebook del elenco vs Gross
# **Interpretación**: Se percibe una relación positiva, pero con muchos valores extremos. Esto sugiere que la popularidad en redes sociales puede ser un factor relevante, aunque con influencia variable.
#
# **Nota estadística**: La línea roja representa la regresión lineal ajustada a los datos. La dispersión de los puntos alrededor de esta línea indica qué tan bien se ajusta el modelo lineal a los datos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 5))

# 1. imdb_score vs gross
plt.subplot(1, 3, 1)
sns.regplot(data=df, x='imdb_score', y='gross', scatter_kws={'alpha':0.5}, line_kws={"color": "red"})
plt.title("IMDB Score vs Gross")
plt.xlabel("IMDB Score")
plt.ylabel("Ganancia (Gross)")

# 2. num_voted_users vs gross
plt.subplot(1, 3, 2)
sns.regplot(data=df, x='num_voted_users', y='gross', scatter_kws={'alpha':0.3}, line_kws={"color": "red"})
plt.title("Votos de usuarios vs Gross")
plt.xlabel("Número de votos")
plt.ylabel("Ganancia (Gross)")

# 3. cast_total_facebook_likes vs gross
plt.subplot(1, 3, 3)
sns.regplot(data=df, x='cast_total_facebook_likes', y='gross', scatter_kws={'alpha':0.3}, line_kws={"color": "red"})
plt.title("Likes en Facebook del elenco vs Gross")
plt.xlabel("Total de likes del elenco")
plt.ylabel("Ganancia (Gross)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 7: Histograma de los Likes de Actores</font>

# %% [markdown]
# Analizar si los actores o directores más populares en redes sociales están asociados con mayores ingresos o puntuaciones en IMDb.

# %%
# Histograma


# Histograma de likes de actores principales (columna 'actor_1_facebook_likes')
plt.figure(figsize=(10, 6))

# Limitar los valores de 'actor_1_facebook_likes' para eliminar outliers
df_filtered = df[df['actor_1_facebook_likes'] < 200000]  # Ajusta el valor según lo que necesites

# Crear el histograma con un rango de bins ajustado
plt.hist(df_filtered['actor_1_facebook_likes'], bins=30, color='skyblue', edgecolor='black')

# Personalizar el gráfico
plt.title('Distribución de Likes en Facebook de Actores Principales')
plt.xlabel('Likes de Actores principales en Facebook')
plt.ylabel('Frecuencia de peliculas con los actores')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 8: Comparación de Películas con Éxito Crítico vs Éxito de Taquilla</font>

# %% [markdown]
# Permitire una visualización clara de cómo se distribuyen las películas exitosas en ambas dimensiones.

# %%
# Gráfico de barras apiladas

# Crear dos categorías para el éxito crítico y de taquilla
# Definir umbrales para determinar si una película es exitosa en cada dimensión
umbral_critico = df['num_critic_for_reviews'].median()  # Media de críticas
umbral_taquilla = df['gross'].median()  # Media de ingresos de taquilla

# Crear una nueva columna para clasificar el éxito crítico
df['exito_critico'] = df['num_critic_for_reviews'].apply(lambda x: 'Exitoso' if x >= umbral_critico else 'No exitoso')

# Crear una nueva columna para clasificar el éxito en taquilla
df['exito_taquilla'] = df['gross'].apply(lambda x: 'Exitoso en Taquilla' if x >= umbral_taquilla else 'No exitoso en Taquilla')

# Contar el número de películas en cada categoría
exito_combinado = pd.crosstab(df['exito_critico'], df['exito_taquilla'])

# Crear gráfico de barras apiladas
exito_combinado.plot(kind='bar', stacked=True, color=['#4CAF50', '#FF0000'], figsize=(10,6))

# Configuración del gráfico
plt.title('Comparación de Películas con Éxito Crítico vs Éxito en Taquilla')
plt.xlabel('Éxito Crítico')
plt.ylabel('Número de Películas')
plt.xticks(rotation=0)
plt.legend(title="Éxito en Taquilla", loc='upper left')

# Mostrar gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 9: Comparación de algunas estadisticas en el transcurso de los años</font>

# %% [markdown]
# Este gráfico tiene como propósito ofrecer una visión histórica de la cantidad de películas producidas a lo largo del tiempo, agrupadas por década. Esta representación permite identificar fácilmente los periodos de mayor o menor actividad cinematográfica dentro del dataset, evitando la saturación visual que resultaría de mostrar todos los años individualmente.

# %%
plt.figure(figsize=(16, 6))
sns.countplot(data=df, x='title_year', palette='viridis', order=sorted(df['title_year'].dropna().unique()))
plt.title('Cantidad de Películas por Año')
plt.xlabel('Año')
plt.ylabel('Cantidad de Películas')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-1caebc58d448>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='title_year', palette='viridis', order=sorted(df['title_year'].dropna().unique()))

# %% [markdown]
# A continuación se presentan tres gráficas de línea que analizan cómo han evolucionado, a lo largo del tiempo, algunas de las variables más relevantes del dataset: presupuesto (budget), ganancia (gross) y calificación IMDb (imdb_score). Todas las gráficas muestran la media por año, con el objetivo de observar tendencias y cambios en la industria cinematográfica desde una perspectiva estadística.
#
# 1. **Presupuesto promedio (budget) por año**
#
# Esta gráfica muestra el presupuesto promedio destinado a las películas estrenadas cada año. Nos ayuda a visualizar cómo han cambiado las inversiones cinematográficas a lo largo del tiempo.
#
# Se observa un crecimiento progresivo del presupuesto con el paso de las décadas, especialmente desde los años 90 en adelante. Esto refleja el aumento de producción, mejoras tecnológicas, marketing, y también el crecimiento de la industria como negocio global.
#
# 2. **Ganancia promedio (gross) por año**
#
# Esta gráfica representa el promedio de las ganancias brutas (gross) generadas por las películas de cada año.
# Aunque algunos de los valores más altos aparecen en décadas muy antiguas (por ejemplo, 1930s y 1940s). Esto se debe probablemente a:
#
# Baja cantidad de películas registradas en esos años, lo que amplifica el impacto de un solo éxito taquillero.
#
# 3. **Puntuación promedio (imdb_score) por año**
#
# Esta gráfica muestra la calificación promedio en IMDb de las películas por año.
#
# A diferencia de budget y gross, las puntuaciones IMDb tienden a mantenerse en un rango estable (6–7 puntos) a lo largo del tiempo. Se pueden observar ligeras variaciones en ciertas décadas.

# %%
df['title_year'] = pd.to_numeric(df['title_year'], errors='coerce')
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['gross'] = pd.to_numeric(df['gross'], errors='coerce')
df['imdb_score'] = pd.to_numeric(df['imdb_score'], errors='coerce')

df_filtered = df.dropna(subset=['title_year', 'budget', 'gross', 'imdb_score'])
df_yearly = df_filtered.groupby('title_year')[['budget', 'gross', 'imdb_score']].mean()

plt.figure(figsize=(18, 5))

# grafica de budget
plt.subplot(1, 3, 1)
sns.lineplot(x=df_yearly.index, y=df_yearly['budget'], marker="o")
plt.title('Presupuesto Promedio por Año')
plt.xlabel('Año')
plt.ylabel('Presupuesto (USD)')

# Grafica de gross
plt.subplot(1, 3, 2)
sns.lineplot(x=df_yearly.index, y=df_yearly['gross'], marker="o", color='green')
plt.title('Ganancia Promedio por Año')
plt.xlabel('Año')
plt.ylabel('Ganancia (USD)')

# Grafica de imdb_score
plt.subplot(1, 3, 3)
sns.lineplot(x=df_yearly.index, y=df_yearly['imdb_score'], marker="o", color='orange')
plt.title('IMDB Score Promedio por Año')
plt.xlabel('Año')
plt.ylabel('IMDB Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## <font color='#5BFFB1'>Gráfico 9: Teoremas celebres</font>

# %% [markdown]
# La **media poblacional** de una variable \( X \) se define como:
#
# $$
# \mu = \frac{1}{N} \sum_{i=1}^{N} x_i
# $$
# Donde:
# - $ \mu $: es la media poblacional,
# - $ x_i $: es el valor de cada observación,
# - $ N $: es el número total de datos.
#
# La **desviación estándar poblacional** se define como:
#
# $$
# \sigma = \sqrt{ \frac{1}{N} \sum_{i=1}^{N} (x_i - \mu)^2 }
# $$
# Donde:
# - $\sigma$: es la desviación estándar poblacional,
# - $\mu$: es la media,
# - $x_i$: es cada valor observado,
# - $N$: es el número total de datos.
#
# La **función de densidad de probabilidad** de una distribución normal es:
#
# $$
# f(x) = \frac{1}{\sqrt{2\pi\sigma^2}} \cdot e^{ -\frac{(x - \mu)^2}{2\sigma^2} }
# $$
# Donde:
# - $ F(x) $: es la densidad de probabilidad para el valor \( x \),
# - $ \mu $: es la media,
# - $ \sigma $: es la desviación estándar.
#
# Entonces en el dataset vamos a hallar la distribucion empírica obteniendo la media y desviación estandar de los datos originales, graficamos el histograma y una curva de densidad.

# %%
from scipy.stats import norm

data = df['gross'].dropna()

plt.figure(figsize=(10, 6))

sns.histplot(data, bins=30, kde=True, color='skyblue', edgecolor='black', stat='density', label='Datos originales')

# Opcional: Añadir una curva normal teórica para comparar
mean, std = data.mean(), data.std()
x = np.linspace(min(data), max(data), 100)
plt.plot(x, norm.pdf(x, mean, std), 'r--', label='Normal teórica')

# Personalización
plt.title('Distribución Original de la Variable "gross"', fontsize=16)
plt.xlabel('Ingresos brutos (gross)', fontsize=12)
plt.ylabel('Densidad', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Teorema del Límite Central**
#
# Este teorema establece que, si tomamos múltiples muestras aleatorias de tamaño suficientemente grande ($n \geq 30$) de una población con media $\mu$ y desviación estándar $\sigma$, la distribución de las medias muestrales $\bar{X}$ tiende a una distribución normal:
#
# $$
# \bar{X} \sim \mathcal{N}\left(\mu, \frac{\sigma^2}{n} \right)
# $$
#
# Esto significa que la media muestral seguirá una distribución normal, sin importar la distribución original de los datos.

# %%
from scipy.stats import norm

#Nueva variable: data
data = df['gross'].dropna()
sample_means = []

#Bucle para crear el array
for _ in range(1000):
    sample = np.random.choice(data, size=30, replace=True)
    sample_means.append(np.mean(sample))

mean_mu = np.mean(sample_means)
std_sigma = np.std(sample_means)

#Grafica
plt.figure(figsize=(10, 6))
sns.histplot(sample_means, bins=30, kde=False, stat='density', color='skyblue', edgecolor='black', label='Distribución muestral')
x = np.linspace(min(sample_means), max(sample_means), 100)
plt.plot(x, norm.pdf(x, mean_mu, std_sigma), 'r--', label='Curva normal teórica')
plt.title('Teorema del Límite Central aplicado al gross')
plt.xlabel('Media de muestra')
plt.ylabel('Densidad')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Independencia entre media y varianza muestrales**
#
# Si los datos $X_1, X_2, \dots, X_n$ provienen de una distribución normal, entonces la media muestral $\bar{X}$ y la varianza muestral $S^2$ son variables aleatorias **independientes**:
#
# $$
# S^2 = \frac{1}{n - 1} \sum_{i=1}^{n} (X_i - \bar{X})^2
# $$
#
# Este resultado solo se cumple si los datos provienen de una **distribución normal**.
#
#  El objetivo es observar si hay una dependencia entre ambas. Esto permite explorar la validez de una propiedad estadística clave. Si los puntos están dispersos sin una tendencia clara, sugiere independencia.

# %%
#Variables
medias = []
varianzas = []

#Tomamos 1000 muestras de 'gross' y añadimos al array
for _ in range(5000):
    muestra = np.random.choice(data, size=30, replace=True)
    medias.append(np.mean(muestra))
    varianzas.append(np.var(muestra, ddof=1))

#Grafico
plt.figure(figsize=(8,5))
plt.scatter(medias, varianzas, alpha=0.5)
plt.title('Relación entre media y varianza muestral')
plt.xlabel('Media')
plt.ylabel('Varianza')
plt.grid(True)
plt.show()

# %% [markdown]
# **Ley de los grandes numeros**
#
# Se genera una curva que muestra la media acumulada y se compara con la media real de todo el dataset. Esto demuestra la Ley de los Grandes Números, que afirma que la media muestral converge a la verdadera medida poblacional al aumentar el tamaño de la muestra. El gráfico ilustra cómo esa convergencia sucede progresivamente.
#
# La ley establece que, al aumentar el número de observaciones $n$, la media muestral $\bar{X}_n$ se aproxima a la media poblacional $\mu$:
#
# $$
# \lim_{n \to \infty} \bar{X}_n = \mu \quad \text{(con alta probabilidad)}
# $$
#
# Es decir, con suficientes datos, nuestras estimaciones se vuelven más confiables.

# %%
#Variables
media_real = np.mean(data)
medias_acumuladas = []

#Añadimos el promedio de cada fila de 'gross'
for n in range(1, len(data)):
    medias_acumuladas.append(np.mean(data[:n]))

#Grafica
plt.figure(figsize=(10,5))
plt.plot(medias_acumuladas, label='Media muestral acumulada')
plt.axhline(media_real, color='red', linestyle='--', label='Media real')
plt.title('Ley de los Grandes Números')
plt.xlabel('Tamaño de la muestra')
plt.ylabel('Media')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # <font color='#9BFDFF'>**Bibliografía**</font>
#
#
# ---

# %% [markdown]
# <h3>
#
# 1.   De Vany, A., & Walls, W. D. (1999). Uncertainty in the Movie Industry:     Does Star Power Reduce the Terror of the Box Office? Journal of Cultural Economics, 23(4), 285–318.
# 2.   Wallace, W., Seigerman, A., & Holbrook, M. (2016). The Role of Critics in the Culture of the Movie Industry. Journal of Marketing, 61(2), 42–55.
# 3.  Mishra, A., & Rout, H. K. (2020). Social Media and the Film Industry: Measuring Popularity and Success. International Journal of Communication, 14, 1365–1383.
# 4.  Konnikova, M. (2014). How ‘Frozen’ Took Over the World. The New Yorker. https://www.newyorker.com
