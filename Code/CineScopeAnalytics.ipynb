# %% [markdown]
# <h1> <strong> Definición y Análisis del Éxito Cinematográfico: Un Enfoque Multidimensional Basado en Indicadores Cuantitativos y Cualitativos 🎬 </strong> </h1>

# %% [markdown]
# ![IntodructionImage_Stastics.png](data:image/png;base64,...)

# %% [markdown]
# <section>
#   <h1> <strong> Introducción </strong> </h1>
#
#   <h2> <strong> Integrantes: </strong> </h2>
#     <ul>
#       <li> Edgar Santiago Ariza García - 2211881 </li>
#       <li> Integrante 2 </li>
#       <li> Integrante 3 </li>
#     </ul>
#
#   <h2> <strong> Contexto: </strong> </h2>
#     <p> El éxito de una película es un concepto complejo que involucra una variedad de factores, más allá de los ingresos brutos obtenidos en taquilla. En este proyecto, se busca explorar cómo distintos indicadores pueden definir el éxito de una película, no solo desde el punto de vista financiero, sino también desde el reconocimiento crítico y la aceptación del público. </p>
#     <p> Para ello, se utiliza un dataset que contiene información sobre 3,755 películas, con variables como la duración, el presupuesto, los ingresos brutos, las puntuaciones en IMDb, los votos de usuarios, y más. A través del análisis de estos datos, se establecerán criterios de éxito cinematográfico que permitirán evaluar las películas bajo diversas perspectivas. </p>
#     <p> El análisis se centrará en cuatro aspectos clave: la puntuación en IMDb, los ingresos brutos, el número de votos de usuarios, y el reconocimiento crítico. Estos indicadores se seleccionan debido a su relevancia en estudios previos sobre el tema y su capacidad para reflejar tanto la popularidad de las películas como su valoración a largo plazo. </p>
#
#   <h2> <strong> Marco Teorico: </strong> </h2>
#     <p> El éxito de una película es un concepto complejo que involucra una variedad de factores, más allá de los ingresos brutos obtenidos en taquilla. En este proyecto, se busca explorar cómo distintos indicadores pueden definir el éxito de una película, no solo desde el punto de vista financiero, sino también desde el reconocimiento crítico y la aceptación del público. </p>
#     <p> Para ello, se utiliza un dataset que contiene información sobre 3,755 películas, con variables como la duración, el presupuesto, los ingresos brutos, las puntuaciones en IMDb, los votos de usuarios, y más. A través del análisis de estos datos, se establecerán criterios de éxito cinematográfico que permitirán evaluar las películas bajo diversas perspectivas.</p>
#     <p> El análisis se centrará en cuatro aspectos clave: la puntuación en IMDb, los ingresos brutos, el número de votos de usuarios, y el reconocimiento crítico. Estos indicadores se seleccionan debido a su relevancia en estudios previos sobre el tema y su capacidad para reflejar tanto la popularidad de las películas como su valoración a largo plazo. </p>
#
# </section>

# %% [markdown]
# <section>
#
#   <h1> <strong> DataSet: </strong> </h1>
#     <p> Para este análisis, se seleccionaron cuatro criterios fundamentales que se consideran indicadores clave del éxito cinematográfico: </p> <br>
#     <h2> <strong> 1) Puntuación en IMDb (≥ 7.0): </strong> </h2>
#       <p> Justificación: IMDb es una de las plataformas más influyentes para la opinión
#       del público. Las películas con una puntuación igual o superior a 7.0 suelen ser vistas como de alta calidad, ya que reflejan una valoración positiva por parte de una audiencia amplia. Un estudio de Wallace et al. (2016) sugiere que las películas con alta calificación en IMDb tienden a mantenerse relevantes a largo plazo, pues la valoración del público influye directamente en su permanencia en la memoria colectiva. <br>
#       <strong> Fuente: </strong> Wallace, W., Seigerman, A., & Holbrook, M. (2016). The Role of Critics in the Culture of the Movie Industry. Journal of Marketing, 61(2), 42–55. </p> <br>
#     <h2> <strong> 2) Ingresos Brutos (superiores a la mediana del dataset):  </strong> </h2>
#       <p> Justificación: Los ingresos brutos son un indicador directo de la rentabilidad financiera de una película. Sin embargo, los ingresos deben analizarse en relación con el presupuesto de producción para obtener una medida precisa de éxito financiero. De Vany y Walls (1999) argumentan que el retorno de inversión es un factor crítico, pero debe ser considerado dentro de un contexto que contemple la incertidumbre inherente a la industria cinematográfica. <br>
#       <strong> Fuente: </strong> De Vany, A., & Walls, W. D. (1999). Uncertainty in the Movie Industry: Does Star Power Reduce the Terror of the Box Office? Journal of Cultural Economics, 23(4), 285–318. </p> <br>
#     <h2> <strong> 3) Votos de Usuarios (más de 100,000 votos): </strong> </h2>
#       <p> Justificación: El número de votos y reseñas en plataformas como IMDb refleja la popularidad y aceptación de una película entre el público general. Las películas que generan una mayor interacción y participación por parte de los usuarios tienden a ser más exitosas en términos de popularidad y tienen un impacto más duradero. Mishra y Rout (2020) destacan que las métricas sociales y de engagement digital permiten una mejor estimación del éxito de una película desde la perspectiva del público general. <br>
#       <strong> Fuente: </strong> Mishra, A., & Rout, H. K. (2020). Social Media and the Film Industry: Measuring Popularity and Success. International Journal of Communication, 14, 1365–1383. </p> <br>
#     <h2> <strong> 4) Reconocimiento Crítico (premios y distinciones): </strong> </h2>
#       <p> Justificación: El reconocimiento crítico es esencial para evaluar la importancia artística de una película. Las películas que reciben elogios de la crítica y ganan premios importantes, como los Óscar o los Globos de Oro, tienen un valor cultural significativo que las distingue de otras películas. Konnikova (2014) menciona que algunas películas, como "Frozen", logran un impacto cultural profundo más allá de su rendimiento financiero, gracias a su resonancia emocional y narrativa. <br>
#       <strong> Fuente: </strong> Konnikova, M. (2014). How ‘Frozen’ Took Over the World. The New Yorker. https://www.newyorker.com </p>
#
# </section>

# %% [markdown]
# <h1> Establecer el drive. </h1>

# %%
import os
from google.colab import drive

path_stastics = "CineScopeAnalytics/Code" #@param {type:"string"}
path = "/content/drive/MyDrive/" + path_stastics
drive.mount('/content/drive')
os.chdir(path)
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/CineScopeAnalytics/Code

# %% [markdown]
# <h1> Importar las librerias. </h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h1> Cargar el dataset </h1>

# %%
df = pd.read_csv("movie_metadata.csv")
data = pd.concat([df], ignore_index=True)
print(data.head())
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# <h1> Limpieza de datos </h1>

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
# Total de filas
total_filas = len(df)

# Filas con 'gross' nulo
filas_nulas = df['gross'].isnull().sum()

# Proporción de datos perdidos
print(f"Se eliminarían {filas_nulas} de {total_filas} filas ({(filas_nulas / total_filas) * 100:.2f}%)")
# Out:
# Se eliminarían 884 de 5043 filas (17.53%)

# %% [markdown]
# <h1> Eliminamos las Filas Nan </h1>

# %%
df = df.dropna(subset=['gross'])

# %% [markdown]
# <h1> Histogramas y Pieplots: </h1>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cols_to_convert = ['budget', 'gross', 'duration', 'imdb_score',
                   'num_critic_for_reviews', 'num_user_for_reviews',
                   'num_voted_users', 'title_year']
for col in cols_to_convert:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df['main_genre'] = df['genres'].apply(lambda x: x.split('|')[0] if isinstance(x, str) else x)

fig, axs = plt.subplots(3, 3, figsize=(18, 15))
fig.suptitle("Visualización exploratoria de variables relacionadas al éxito (gross)", fontsize=18)

# 1. Histograma: presupuesto
df_log = df[df['budget'] > 0].copy()
df_log['log_budget'] = np.log10(df_log['budget'])

sns.histplot(df_log['log_budget'], bins=10, kde=True, ax=axs[0,0], color='skyblue')
axs[0,0].set_title("Presupuesto (escala log)")
axs[0,0].set_xlabel("log10(Presupuesto en USD)")

# 2. Histograma: duración
sns.histplot(df['duration'], bins=30, kde=True, ax=axs[0,1], color='lightgreen')
axs[0,1].set_title("Duración")

# 3. Histograma: puntaje IMDb
sns.histplot(df['imdb_score'], bins=20, kde=True, ax=axs[0,2], color='salmon')
axs[0,2].set_title("Puntaje IMDb")

# 4. Histograma: críticas de expertos
sns.histplot(df['num_critic_for_reviews'], bins=30, kde=True, ax=axs[1,0], color='orange')
axs[1,0].set_title("Críticas de expertos")

# 5. Histograma: críticas de usuarios
sns.histplot(df['num_user_for_reviews'], bins=30, kde=True, ax=axs[1,1], color='orchid')
axs[1,1].set_title("Críticas de usuarios")

# 6. Histograma: votos de usuarios
sns.histplot(df['num_voted_users'], bins=30, kde=True, ax=axs[1,2], color='teal')
axs[1,2].set_title("Votos de usuarios")

# 7. Piechart: Clasificación por edad
rating_counts = df['content_rating'].value_counts(normalize=True)
rating_grouped = df['content_rating'].apply(
    lambda x: x if x in rating_counts and rating_counts[x] >= 0.03 else 'Otros'
)
rating_grouped.value_counts().plot.pie(
    autopct='%1.1f%%', ax=axs[2,0], startangle=90, shadow=True,
    colors=sns.color_palette('pastel'), wedgeprops={'edgecolor': 'black'}
)
axs[2,0].set_title("Clasificación por edad (agrupado)")
axs[2,0].set_ylabel('')


# 8. Barras: género principal
df['main_genre'].value_counts().plot(kind='bar', ax=axs[2,1], color='plum')
axs[2,1].set_title("Género principal")
axs[2,1].set_xlabel("Género")
axs[2,1].set_ylabel("Cantidad")
axs[2,1].tick_params(axis='x', rotation=45)

# 9. Histograma: año de lanzamiento
sns.histplot(df['title_year'], bins=20, ax=axs[2,2], color='lightcoral')
axs[2,2].set_title("Año de lanzamiento")

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# <h1> HeatMap: Relación lineal </h1>

# %% [markdown]
# **Objetivo**: Explorar las correlaciones lineales entre variables cuantitativas como presupuesto, duración, puntuación IMDB y ganancias (`gross`) para identificar relaciones potenciales.
#
# **Descripción**: Este heatmap muestra una matriz de correlaciones de Pearson entre seis variables numéricas del dataset. El color azul indica correlaciones negativas, el rojo correlaciones positivas, y el valor numérico representa la magnitud de la correlación.
#
# **Interpretación**:
# - Una correlación cercana a **1** indica una relación lineal fuerte y positiva.
# - Una correlación cercana a **-1** indica una relación lineal fuerte pero negativa.
# - Una correlación cercana a **0** sugiere que no hay relación lineal.
#
# **Conclusiones preliminares**:
# - Existe una correlación positiva entre `budget` con `num_critic_for_reviews` y `movie_facebook_likes`, lo que sugiere que la popularidad y mayor exponencia al publico puede asociarse con mayores ganancias.
# - `imdb_score` tiene una relación débil con las demás variables, indicando que una buena puntuación no garantiza éxito económico.

# %%
import pandas as pd

for col in ['budget', 'gross', 'duration', 'num_critic_for_reviews', 'imdb_score', 'movie_facebook_likes']:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df = df.dropna(subset=['budget', 'duration'])

df_num = df[['budget', 'gross', 'duration', 'num_critic_for_reviews', 'imdb_score', 'movie_facebook_likes']]

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df_num.corr(), annot=True, cmap="bwr", fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlaciones Lineal Cinematica')
plt.show()

# %% [markdown]
# <h1> ScatterPlots: </h1>

# %% [markdown]
# ## Relación entre variables explicativas y las ganancias (Gross)
#
# **Objetivo**: Analizar la relación individual entre tres variables predictoras (`imdb_score`, `num_voted_users`, `cast_total_facebook_likes`) y las ganancias (`gross`) para detectar tendencias.
#
# ### 1. IMDB Score vs Gross
# **Interpretación**: Se observa una tendencia levemente creciente, pero con alta dispersión. A pesar de que una mejor puntuación puede influir positivamente, no es un factor decisivo por sí solo.
#
# ### 2. Número de votos vs Gross
# **Interpretación**: Aquí sí hay una **relación más clara**. A medida que aumenta el número de votos de usuarios, también tiende a aumentar la ganancia. Esto puede indicar que películas más vistas o discutidas tienen mejor desempeño económico.
#
# ### 3. Likes en Facebook del elenco vs Gross
# **Interpretación**: Se percibe una relación positiva, pero con muchos valores extremos. Esto sugiere que la popularidad en redes sociales puede ser un factor relevante, aunque con influencia variable.
#
# **Nota estadística**: La línea roja representa la regresión lineal ajustada a los datos. La dispersión de los puntos alrededor de esta línea indica qué tan bien se ajusta el modelo lineal a los datos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 5))

# 1. imdb_score vs gross
plt.subplot(1, 3, 1)
sns.regplot(data=df, x='imdb_score', y='gross', scatter_kws={'alpha':0.5}, line_kws={"color": "red"})
plt.title("IMDB Score vs Gross")
plt.xlabel("IMDB Score")
plt.ylabel("Ganancia (Gross)")

# 2. num_voted_users vs gross
plt.subplot(1, 3, 2)
sns.regplot(data=df, x='num_voted_users', y='gross', scatter_kws={'alpha':0.3}, line_kws={"color": "red"})
plt.title("Votos de usuarios vs Gross")
plt.xlabel("Número de votos")
plt.ylabel("Ganancia (Gross)")

# 3. cast_total_facebook_likes vs gross
plt.subplot(1, 3, 3)
sns.regplot(data=df, x='cast_total_facebook_likes', y='gross', scatter_kws={'alpha':0.3}, line_kws={"color": "red"})
plt.title("Likes en Facebook del elenco vs Gross")
plt.xlabel("Total de likes del elenco")
plt.ylabel("Ganancia (Gross)")

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> Distribución binomial </h1>

# %% [markdown]
#  En este análisis se ha definido el "éxito financiero" como lograr una ganancia de al menos 1.5 veces el presupuesto invertido. Usamos un modelo probabilístico binomial para estimar la probabilidad de observar cierto número de películas exitosas en una muestra de películas. Como la muestra es grande, usamos una aproximación normal para representar mejor la distribución esperada de éxitos. Esto nos ayuda a visualizar cómo se comporta el éxito en el cine desde una perspectiva estadística.

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

# Consideramos el exito como la ganancia

df['exito_financiero'] = df['gross'] >= 1.5 * df['budget']

# Usamos las columnas sobrantes

grupo = df.dropna(subset=['budget', 'gross'])

n = len(grupo)
k = grupo['exito_financiero'].sum()
p_hat = k / n

print(f"Total de películas: {n}")
print(f"Éxitos observados: {k}")
print(f"Probabilidad empírica de éxito: {p_hat:.2f}")

# Hacemos el plot

x = range(n+1)
binom_dist = binom.pmf(x, n, p_hat)

plt.figure(figsize=(10, 5))
plt.bar(x, binom_dist, color='skyblue')
plt.axvline(k, color='red', linestyle='--', label=f'Observado: {k} éxitos')
plt.title('Distribución Binomial')
plt.xlabel('Número de Éxitos')
plt.ylabel('Probabilidad')
plt.legend()
plt.tight_layout()
plt.show()

# Graficamos una muestra

sample_df = df.dropna(subset=['budget', 'gross']).sample(30, random_state=1)
sample_df['exito_financiero'] = sample_df['gross'] >= 1.5 * sample_df['budget']

n = len(sample_df)
k = sample_df['exito_financiero'].sum()
p_hat = k / n
# Out:
# Total de películas: 3891
# Éxitos observados: 1472
# Probabilidad empírica de éxito: 0.38

# %% [markdown]
# <h1> Bibliografía: </h1>
#   <ol>
#     <li> De Vany, A., & Walls, W. D. (1999). Uncertainty in the Movie Industry:     Does Star Power Reduce the Terror of the Box Office? Journal of Cultural Economics, 23(4), 285–318. </li>
#     <li> Wallace, W., Seigerman, A., & Holbrook, M. (2016). The Role of Critics in the Culture of the Movie Industry. Journal of Marketing, 61(2), 42–55. </li>
#     <li> Mishra, A., & Rout, H. K. (2020). Social Media and the Film Industry: Measuring Popularity and Success. International Journal of Communication, 14, 1365–1383. </li>
#     <li> Konnikova, M. (2014). How ‘Frozen’ Took Over the World. The New Yorker. https://www.newyorker.com </li>
#   </ol>
